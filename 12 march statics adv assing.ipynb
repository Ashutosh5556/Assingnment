# %%
#ans 1
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 50
Sample standard deviation (
𝑠
s) = 5
Sample size (
𝑛
n) = 1 (typically would be given, but if this is just a sample stat, it can be an error or missing context).
We'll assume a reasonable sample size for this problem (e.g., 
𝑛
=
30
n=30).
import scipy.stats as stats

# Given data
mean = 50
std_dev = 5
sample_size = 30

# Calculate the 95% confidence interval
confidence_level = 0.95
degrees_freedom = sample_size - 1
confidence_interval = stats.t.interval(confidence_level, degrees_freedom, loc=mean, scale=std_dev/ (sample_size ** 0.5))

print(f"95% Confidence Interval: {confidence_interval}")
Interpretation:
The output will give you the range within which the true population mean is expected to fall with 95% confidence. If the confidence interval is (48.13, 51.87), it means we are 95% confident that the true mean lies between 48.13 and 51.87.

# %%
#ans 2
Given:

Expected distribution: 20% blue, 20% orange, 20% green, 10% yellow, 10% red, 20% brown
Observed counts (you'll need to provide the actual counts from your sample).
import scipy.stats as stats

# Observed counts (example)
observed = [35, 30, 25, 10, 5, 20]

# Expected counts based on percentages
expected = [20, 20, 20, 10, 10, 20]

# Perform chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(observed, f_exp=expected)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
Interpretation:
The Chi-Square statistic gives the measure of the discrepancy between the observed and expected frequencies.
The p-value helps determine whether to reject the null hypothesis. If the p-value is less than 0.05, reject the null hypothesis, indicating that the distribution of M&Ms differs significantly from the expected distribution.

# %%
#ans 3
import scipy.stats as stats
import numpy as np

# Contingency table
observed = np.array([[20, 10, 15],
                     [15, 25, 20]])

# Perform the Chi-Square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies: \n{expected}")
# Out:
# Chi-Square Statistic: 5.833333333333334
# P-value: 0.05411376622282158
# Degrees of Freedom: 2
# Expected Frequencies:
# [[15. 15. 15.]
#  [20. 20. 20.]]

# %%
#ans 4
import statsmodels.api as sm

# Sample data
n = 500
smokers = 60

# Proportion of smokers
p_hat = smokers / n

# Calculate the 95% confidence interval
confidence_interval = sm.stats.proportion_confint(smokers, n, alpha=0.05, method='normal')

print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# 95% Confidence Interval: (0.09151638887130706, 0.14848361112869293)

# %%
#ans 5
import scipy.stats as stats

# Given data
mean = 75
std_dev = 12
sample_size = 30

# Calculate the 90% confidence interval
confidence_level = 0.90
degrees_freedom = sample_size - 1
confidence_interval = stats.t.interval(confidence_level, degrees_freedom, loc=mean, scale=std_dev/ (sample_size ** 0.5))

print(f"90% Confidence Interval: {confidence_interval}")
# Out:
# 90% Confidence Interval: (71.27739919800369, 78.72260080199631)

# %%
#ans 6
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom
df = 10

# Generate the chi-square distribution data
x = np.linspace(0, 30, 1000)
y = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, y, label=f'Chi-Square Distribution df={df}')

# Shade the area for chi-square statistic = 15
x_shade = np.linspace(15, 30, 1000)
y_shade = stats.chi2.pdf(x_shade, df)
plt.fill_between(x_shade, y_shade, color='red', alpha=0.5, label='Area for Chi-Square Statistic = 15')

# Label the plot
plt.title('Chi-Square Distribution with 10 Degrees of Freedom')
plt.xlabel('Chi-Square Statistic')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
#ans 7
import statsmodels.api as sm

# Sample data
n = 1000
prefer_coke = 520

# Proportion preferring Coke
p_hat = prefer_coke / n

# Calculate the 99% confidence interval
confidence_interval = sm.stats.proportion_confint(prefer_coke, n, alpha=0.01, method='normal')

print(f"99% Confidence Interval: {confidence_interval}")
# Out:
# 99% Confidence Interval: (0.4793051576779699, 0.5606948423220302)

# %%
#ans 8
import scipy.stats as stats

# Observed frequencies
observed = [45, 55]

# Expected frequencies for a fair coin
expected = [50, 50]

# Perform chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(observed, f_exp=expected)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
# Out:
# Chi-Square Statistic: 1.0
# P-value: 0.31731050786291115

# %%
#ans 9
import scipy.stats as stats
import numpy as np

# Contingency table
observed = np.array([[60, 40],
                     [30, 70]])

# Perform the Chi-Square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies: \n{expected}")
# Out:
# Chi-Square Statistic: 16.98989898989899
# P-value: 3.7579211012441855e-05
# Degrees of Freedom: 1
# Expected Frequencies:
# [[45. 55.]
#  [45. 55.]]

# %%
#ans 10
import scipy.stats as stats
import numpy as np

# Contingency table data (example)
observed = np.array([[200, 150, 150],
                     [180, 170, 150]])

# Perform the Chi-Square test for independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies: \n{expected}")
# Out:
# Chi-Square Statistic: 2.302631578947368
# P-value: 0.31622041602767087
# Degrees of Freedom: 2
# Expected Frequencies:
# [[190. 160. 150.]
#  [190. 160. 150.]]

# %%
#ans 11
import scipy.stats as stats

# Given data
sample_mean = 72
sample_std_dev = 10
sample_size = 30
hypothesized_mean = 70

# Calculate the t-statistic
t_stat = (sample_mean - hypothesized_mean) / (sample_std_dev / (sample_size ** 0.5))

# Calculate the p-value
p_value = 2 * stats.t.sf(abs(t_stat), df=sample_size - 1)

print(f"T-Statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
# T-Statistic: 1.0954451150103321
# P-value: 0.28233623728606977
