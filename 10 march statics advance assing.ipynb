# %%
# ans 1
**Estimation statistics** involves making inferences about a population based on sample data.

- **Point Estimate**: A single value (e.g., sample mean) used to estimate a population parameter.
  
- **Interval Estimate**: A range of values, along with a confidence level, within which the population parameter is likely to lie (e.g., a 95% confidence interval).

# %%
#ans 2
import scipy.stats as stats
import numpy as np

def estimate_population_mean(sample_mean, sample_std, sample_size, confidence_level=0.95):
    """
    Estimate the population mean and calculate the confidence interval.
    
    Parameters:
    - sample_mean: The mean of the sample
    - sample_std: The standard deviation of the sample
    - sample_size: The size of the sample
    - confidence_level: The confidence level for the interval (default is 0.95)
    
    Returns:
    - (mean_estimate, lower_bound, upper_bound): A tuple containing the estimated mean and the confidence interval
    """
    # Calculate the standard error of the mean
    standard_error = sample_std / np.sqrt(sample_size)
    
    # Calculate the critical value (z-score) for the given confidence level
    z_score = stats.norm.ppf((1 + confidence_level) / 2)
    
    # Calculate the margin of error
    margin_of_error = z_score * standard_error
    
    # Calculate the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    return sample_mean, lower_bound, upper_bound

# Example usage
sample_mean = 50
sample_std = 10
sample_size = 100

mean_estimate, lower_bound, upper_bound = estimate_population_mean(sample_mean, sample_std, sample_size)
print(f"Estimated Mean: {mean_estimate}")
print(f"95% Confidence Interval: ({lower_bound}, {upper_bound})")
# Out:
# Estimated Mean: 50
# 95% Confidence Interval: (48.04003601545995, 51.95996398454005)

# %%
#ans 3
What is Hypothesis Testing?
Hypothesis testing is a statistical method used to make decisions or inferences about a population parameter based on sample data. It involves testing an assumption (called a hypothesis) about a population parameter, such as the mean or proportion. The process compares observed data against what would be expected under the assumption of the hypothesis.

Why is it Used?
Hypothesis testing is used to determine whether there is enough evidence in a sample of data to support or reject a specific claim about a population. It helps in making informed decisions by evaluating whether the observed effects or differences in the data are statistically significant or could have occurred by random chance.

Importance of Hypothesis Testing
Decision Making: Hypothesis testing provides a structured framework for making decisions based on data. It helps in evaluating whether a new treatment, process, or intervention is effective compared to a standard or existing one.

Scientific Research: In research, hypothesis testing is fundamental to validating theories, models, and experimental results. It allows researchers to test the validity of their hypotheses and draw conclusions that are backed by statistical evidence.

Quality Control: In industries, hypothesis testing is used for quality control and process improvement. It helps in determining whether a product or process meets the required standards and whether any observed variation is due to random factors or a real issue.

Risk Management: Hypothesis testing aids in assessing risks by evaluating whether observed outcomes are likely due to chance or a significant underlying factor, thereby guiding decision-making in uncertain situations.

Policy Making: Governments and organizations use hypothesis testing to evaluate the impact of policies and programs, ensuring that decisions are based on reliable and statistically sound evidence.

# %%
#ans 4
Here’s how you can formulate a hypothesis to test whether the average weight of male college students is greater than that of female college students:

Null Hypothesis (H₀):
H₀: The average weight of male college students is less than or equal to the average weight of female college students.
Symbolically: 
𝜇
male
≤
𝜇
female
μ 
male
​
 ≤μ 
female
​
 
Alternative Hypothesis (H₁):
H₁: The average weight of male college students is greater than the average weight of female college students.
Symbolically: 
𝜇
male
>
𝜇
female
μ 
male
​
 >μ 
female
​
 
Explanation:
H₀ (Null Hypothesis) assumes that there is no significant difference or that the average weight of male students is not greater than that of female students.
H₁ (Alternative Hypothesis) posits that the average weight of male students is indeed greater than that of female students.
This is an example of a one-tailed test, as the interest is specifically in testing whether one mean is greater than the other, not simply different.

# %%
#ans 5
import numpy as np
from scipy import stats

def two_sample_t_test(sample1, sample2, equal_var=True):
    """
    Conducts a two-sample t-test to compare the means of two populations.
    
    Parameters:
    - sample1: List or array of sample data from the first population
    - sample2: List or array of sample data from the second population
    - equal_var: Whether to assume equal variances (default is True)
    
    Returns:
    - t_statistic: The computed t-statistic
    - p_value: The p-value of the test
    """
    # Perform the two-sample t-test
    t_statistic, p_value = stats.ttest_ind(sample1, sample2, equal_var=equal_var)
    
    return t_statistic, p_value

# Example usage
sample1 = [22, 25, 27, 30, 32]  # Sample data from first population
sample2 = [20, 23, 25, 28, 29]  # Sample data from second population

t_statistic, p_value = two_sample_t_test(sample1, sample2)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two means.")
# Out:
# T-statistic: 0.9103664774626044
# P-value: 0.3892344102084683
# Fail to reject the null hypothesis: There is no significant difference between the two means.

# %%
#ans 6
Null Hypothesis (H₀): A statement that there is no effect or no difference. It is the hypothesis that the test aims to disprove or reject.

Examples:

H₀: There is no difference in the average test scores between two teaching methods.
H₀: The mean weight of male and female students is the same.
Alternative Hypothesis (H₁): A statement that indicates the presence of an effect or a difference. It is what you want to provide evidence for in your test.

Examples:

H₁: There is a difference in the average test scores between two teaching methods.
H₁: The mean weight of male students is different from that of female students.

# %%
#ans 7
Formulate Hypotheses: Define the null hypothesis (H₀) and the alternative hypothesis (H₁).

Select Significance Level: Choose the significance level (α), typically 0.05, which defines the threshold for rejecting H₀.

Collect Data: Gather sample data relevant to the hypotheses.

Perform the Test: Apply an appropriate statistical test (e.g., t-test, z-test) to the data to compute the test statistic and p-value.

Make a Decision: Compare the p-value to the significance level:

If the p-value ≤ α: Reject H₀ (evidence supports H₁).
If the p-value > α: Fail to reject H₀ (not enough evidence to support H₁).
Draw Conclusions: Interpret the results in the context of the problem and report the findings.

Verify Assumptions: Ensure that the assumptions of the statistical test (e.g., normality, variance) are met or discuss any limitations if they are not.

# %%
#ans 8

Q8: P-value and Its Significance
P-value (probability value) is a measure that helps you determine the strength of the evidence against the null hypothesis (H₀). It quantifies the probability of obtaining a test statistic at least as extreme as the one observed, assuming that H₀ is true.

Significance in Hypothesis Testing:
Low P-value (≤ α): Indicates strong evidence against H₀, leading to the rejection of H₀. The results are statistically significant.
High P-value (> α): Suggests weak evidence against H₀, leading to a failure to reject H₀. The results are not statistically significant.
The p-value helps you assess whether the observed data is consistent with the null hypothesis or if there is enough evidence to support the alternative hypothesis.

# %%
#ans 9
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Parameters
df = 10  # Degrees of freedom
x = np.linspace(-5, 5, 1000)  # Range of x values
y = t.pdf(x, df)  # Calculate t-distribution values

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=f"t-distribution (df={df})")
plt.title("Student's t-Distribution")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ans 10\
import numpy as np
from scipy import stats

def two_sample_t_test(sample1, sample2):
    """
    Performs a two-sample t-test for independent samples.
    
    Parameters:
    - sample1: List or array of sample data from the first group
    - sample2: List or array of sample data from the second group
    
    Returns:
    - t_statistic: The computed t-statistic
    - p_value: The p-value of the test
    """
    # Perform the two-sample t-test assuming equal variances
    t_statistic, p_value = stats.ttest_ind(sample1, sample2, equal_var=True)
    
    return t_statistic, p_value

# Example usage
sample1 = [20, 22, 23, 24, 25]  # Sample data from first group
sample2 = [30, 32, 34, 36, 38]  # Sample data from second group

t_statistic, p_value = two_sample_t_test(sample1, sample2)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two means.")
# Out:
# T-statistic: -6.766167445297981
# P-value: 0.00014267082821808235
# Reject the null hypothesis: There is a significant difference between the two means.

# %%
#ans 11
Student’s t Distribution is a family of distributions that are used to estimate population parameters when the sample size is small and/or the population variance is unknown. It is similar in shape to the standard normal distribution but has heavier tails, which makes it more appropriate for small sample sizes.

When to Use:
When the sample size is small (typically less than 30).
When the population standard deviation is unknown.
For hypothesis testing or constructing confidence intervals when the population variance is not known.

# %%
#ans 12
T-Statistic is a value computed from sample data during a t-test, which helps determine whether to reject the null hypothesis. It measures the size of the difference relative to the variation in the sample data.

Formula for T-Statistic:
𝑡
=
𝑋
ˉ
1
−
𝑋
ˉ
2
𝑠
1
2
𝑛
1
+
𝑠
2
2
𝑛
2
t= 
n 
1
​
 
s 
1
2
​
 
​
 + 
n 
2
​
 
s 
2
2
​
 
​
 
​
 
X
ˉ
  
1
​
 − 
X
ˉ
  
2
​
 
​
 

Where:

𝑋
ˉ
1
X
ˉ
  
1
​
  and 
𝑋
ˉ
2
X
ˉ
  
2
​
  are the sample means.
𝑠
1
2
s 
1
2
​
  and 
𝑠
2
2
s 
2
2
​
  are the sample variances.
𝑛
1
n 
1
​
  and 
𝑛
2
n 
2
​
  are the sample sizes.
This formula is used for comparing the means of two independent samples.

# %% [markdown]
# #ans 13
# Given:
#
# Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = $500
# Sample standard deviation (
# 𝑠
# s) = $50
# Sample size (
# 𝑛
# n) = 50
# To calculate the 95% confidence interval for the population mean:
#
# Calculate the Standard Error (SE):
# SE
# =
# 𝑠
# 𝑛
# =
# 50
# 50
# ≈
# 7.07
# SE=
# n
# ​
#
# s
# ​
#  =
# 50
# ​
#
# 50
# ​
#  ≈7.07
#
# Find the Z-score for a 95% Confidence Level:
# For a 95% confidence level, the Z-score is approximately 1.96.
#
# Calculate the Margin of Error (ME):
# ME
# =
# 𝑍
# ×
# SE
# =
# 1.96
# ×
# 7.07
# ≈
# 13.85
# ME=Z×SE=1.96×7.07≈13.85
#
# Calculate the Confidence Interval:
# Lower Bound
# =
# 𝑥
# ˉ
# −
# ME
# =
# 500
# −
# 13.85
# ≈
# 486.15
# Lower Bound=
# x
# ˉ
#  −ME=500−13.85≈486.15
# Upper Bound
# =
# 𝑥
# ˉ
# +
# ME
# =
# 500
# +
# 13.85
# ≈
# 513.85
# Upper Bound=
# x
# ˉ
#  +ME=500+13.85≈513.85

# %%
#ans 14
Null Hypothesis (H₀): The mean decrease in blood pressure is 10 mmHg.
𝐻
0
:
𝜇
=
10
H 
0
​
 :μ=10

Alternative Hypothesis (H₁): The mean decrease in blood pressure is not equal to 10 mmHg.
𝐻
1
:
𝜇
≠
10
H 
1
​
 :μ

=10

Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 8 mmHg
Sample standard deviation (
𝑠
s) = 3 mmHg
Sample size (
𝑛
n) = 100
Significance level (
𝛼
α) = 0.05
Calculate the Standard Error (SE):
SE
=
𝑠
𝑛
=
3
100
=
0.3
SE= 
n
​
 
s
​
 = 
100
​
 
3
​
 =0.3

Calculate the t-statistic:
𝑡
=
𝑥
ˉ
−
𝜇
0
SE
=
8
−
10
0.3
=
−
6.67
t= 
SE
x
ˉ
 −μ 
0
​
 
​
 = 
0.3
8−10
​
 =−6.67

Find the p-value:
Use the t-distribution with 
𝑛
−
1
n−1 degrees of freedom (99). The p-value for 
𝑡
=
−
6.67
t=−6.67 is extremely small (much less than 0.05).

Decision:
Since the p-value < 0.05, reject the null hypothesis.

Conclusion: There is significant evidence to suggest that the mean decrease in blood pressure is different from 10 mmHg.

# %%
#ans 15
Null Hypothesis (H₀): The mean weight of the products is 5 pounds.
𝐻
0
:
𝜇
=
5
H 
0
​
 :μ=5

Alternative Hypothesis (H₁): The mean weight of the products is less than 5 pounds.
𝐻
1
:
𝜇
<
5
H 
1
​
 :μ<5

Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 4.8 pounds
Population standard deviation (
𝜎
σ) = 0.5 pounds
Sample size (
𝑛
n) = 25
Significance level (
𝛼
α) = 0.01
Calculate the Standard Error (SE):
SE
=
𝜎
𝑛
=
0.5
25
=
0.1
SE= 
n
​
 
σ
​
 = 
25
​
 
0.5
​
 =0.1

Calculate the Z-statistic:
𝑍
=
𝑥
ˉ
−
𝜇
0
SE
=
4.8
−
5
0.1
=
−
2
Z= 
SE
x
ˉ
 −μ 
0
​
 
​
 = 
0.1
4.8−5
​
 =−2

Find the p-value:
For 
𝑍
=
−
2
Z=−2, the p-value from the Z-table is approximately 0.0228.

Decision:
Since the p-value (0.0228) > 0.01, fail to reject the null hypothesis.

Conclusion: There is not enough evidence at the 0.01 significance level to conclude that the true mean weight of the products is less than 5 pounds

# %%
#ans 16
Given:

Group 1: 
𝑛
1
=
30
n 
1
​
 =30, mean (
𝑥
ˉ
1
x
ˉ
  
1
​
 ) = 80, standard deviation (
𝑠
1
s 
1
​
 ) = 10
Group 2: 
𝑛
2
=
40
n 
2
​
 =40, mean (
𝑥
ˉ
2
x
ˉ
  
2
​
 ) = 75, standard deviation (
𝑠
2
s 
2
​
 ) = 8
Significance level (
𝛼
α) = 0.01
Null Hypothesis (H₀): The population means of the two groups are equal.
𝐻
0
:
𝜇
1
=
𝜇
2
H 
0
​
 :μ 
1
​
 =μ 
2
​
 

Alternative Hypothesis (H₁): The population means of the two groups are not equal.
𝐻
1
:
𝜇
1
≠
𝜇
2
H 
1
​
 :μ 
1
​
 

=μ 
2
​
 

Calculate the Standard Error (SE) for the difference in means:
SE
=
𝑠
1
2
𝑛
1
+
𝑠
2
2
𝑛
2
=
1
0
2
30
+
8
2
40
=
100
30
+
64
40
=
3.33
+
1.60
=
4.93
≈
2.22
SE= 
n 
1
​
 
s 
1
2
​
 
​
 + 
n 
2
​
 
s 
2
2
​
 
​
 
​
 = 
30
10 
2
 
​
 + 
40
8 
2
 
​
 
​
 = 
30
100
​
 + 
40
64
​
 
​
 = 
3.33+1.60
​
 = 
4.93
​
 ≈2.22

Calculate the Z-statistic:
𝑍
=
𝑥
ˉ
1
−
𝑥
ˉ
2
SE
=
80
−
75
2.22
≈
5
2.22
≈
2.25
Z= 
SE
x
ˉ
  
1
​
 − 
x
ˉ
  
2
​
 
​
 = 
2.22
80−75
​
 ≈ 
2.22
5
​
 ≈2.25

Find the p-value:
For 
𝑍
=
2.25
Z=2.25, the p-value is approximately 0.0245 (two-tailed).

Decision:
Since the p-value (0.0245) > 0.01, fail to reject the null hypothesis.

Conclusion: At the 0.01 significance level, there is not enough evidence to conclude that the population means for the two groups are different.

# %%
#ans 17
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 4
Sample standard deviation (
𝑠
s) = 1.5
Sample size (
𝑛
n) = 50
Confidence level = 99%
Calculate the Standard Error (SE):
SE
=
𝑠
𝑛
=
1.5
50
≈
0.212
SE= 
n
​
 
s
​
 = 
50
​
 
1.5
​
 ≈0.212

Find the Z-score for a 99% Confidence Level:
For a 99% confidence level, the Z-score is approximately 2.576.

Calculate the Margin of Error (ME):

ME
=
𝑍
×
SE
=
2.576
×
0.212
≈
0.546
ME=Z×SE=2.576×0.212≈0.546

Calculate the Confidence Interval:
Lower Bound
=
𝑥
ˉ
−
ME
=
4
−
0.546
≈
3.454
Lower Bound= 
x
ˉ
 −ME=4−0.546≈3.454
Upper Bound
=
𝑥
ˉ
+
ME
=
4
+
0.546
≈
4.546
Upper Bound= 
x
ˉ
 +ME=4+0.546≈4.546

99% Confidence Interval: 3.454 to 4.546
